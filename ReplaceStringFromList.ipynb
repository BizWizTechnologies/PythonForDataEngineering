# %%
lst = ['ApplicationAssignedTo', 'ApplicationAssignedToInvestigator', 'ApplicationAwaiting', 'ApplicationAwaitingInvestigation', 'ApplicationAwaitingQA', 'ApplicationEdit', 'ApplicationReallocated', 'ApplicationReallocationRequested', 'ApplicationRevertedToQueue', 'ApplicationUnassignedFromExaminer', 'ApplicationWithdrawalInitiated', 'BookedInterview', 'CancelledInterview', 'DocumentsRetained',
       'DocumentsTransferredToAms', 'EjectApplication', 'InterviewAwaitingReview', 'InterviewOutcome', 'InvestigationDecisionsSubmitted', 'NotificationDelivered', 'NotificationFailed', 'NotificationSent', 'ObservationEdit', 'PassportPrintFailed', 'PassportReceivedAndChecked', 'PhotoResubmissionRequested', 'RePrintAddressLabel', 'RePrintBarcodeLabel', 'RequestedInterviewExemption', 'ViewPassportDetails']

# %%
print(len(lst))
# Out:
# 30

# %%
for x in lst:
    print(x)
# Out:
# ApplicationAssignedTo
# ApplicationAssignedToInvestigator
# ApplicationAwaiting
# ApplicationAwaitingInvestigation
# ApplicationAwaitingQA
# ApplicationEdit
# ApplicationReallocated
# ApplicationReallocationRequested
# ApplicationRevertedToQueue
# ApplicationUnassignedFromExaminer
# ApplicationWithdrawalInitiated
# BookedInterview
# CancelledInterview
# DocumentsRetained
# DocumentsTransferredToAms
# EjectApplication
# InterviewAwaitingReview
# InterviewOutcome
# InvestigationDecisionsSubmitted
# NotificationDelivered
# NotificationFailed
# NotificationSent
# ObservationEdit
# PassportPrintFailed
# PassportReceivedAndChecked
# PhotoResubmissionRequested
# RePrintAddressLabel
# RePrintBarcodeLabel
# RequestedInterviewExemption
# ViewPassportDetails

# %%
xm="""<changeSet author="msappidi" id="AddIndex-IX_NONCLUS_Atomic_{tbl}_RecordInsertedAt_Remarks" objectQuotingStrategy="QUOTE_ALL_OBJECTS">
	<sql endDelimiter="\\nGO" splitStatements="true" stripComments="true">
	IF NOT EXISTS( SELECT * FROM sys.indexes WHERE name='IX_NONCLUS_Atomic_{tbl}_RecordInsertedAt_Remarks' AND OBJECT_ID = OBJECT_ID('Atomic.{tbl}') )	
	CREATE NONCLUSTERED INDEX [IX_NONCLUS_Atomic_{tbl}_RecordInsertedAt_Remarks]ON [Atomic].[{tbl}] ([RecordInsertedAt],[Remarks])
	</sql>
</changeSet> 
"""
# Out:
# <changeSet author="msappidi" id="AddIndex-IX_NONCLUS_Atomic_XXXX_RecordInsertedAt_Remarks" objectQuotingStrategy="QUOTE_ALL_OBJECTS">
# 	<sql endDelimiter="\nGO" splitStatements="true" stripComments="true">
# 	IF NOT EXISTS( SELECT * FROM sys.indexes WHERE name='IX_NONCLUS_Atomic_XXXX_RecordInsertedAt_Remarks' AND OBJECT_ID = OBJECT_ID('Atomic.XXXX') )
# 	CREATE NONCLUSTERED INDEX [IX_NONCLUS_Atomic_XXXX_RecordInsertedAt_Remarks]ON [Atomic].[XXXX] ([RecordInsertedAt],[Remarks])
# 	</sql>
# </changeSet>

# %%
for x in lst:
    print(xm.format(tbl=x))
# Out:
# <changeSet author="msappidi" id="AddIndex-IX_NONCLUS_Atomic_ApplicationAssignedTo_RecordInsertedAt_Remarks" objectQuotingStrategy="QUOTE_ALL_OBJECTS">
# 	<sql endDelimiter="\nGO" splitStatements="true" stripComments="true">
# 	IF NOT EXISTS( SELECT * FROM sys.indexes WHERE name='IX_NONCLUS_Atomic_ApplicationAssignedTo_RecordInsertedAt_Remarks' AND OBJECT_ID = OBJECT_ID('Atomic.ApplicationAssignedTo') )
# 	CREATE NONCLUSTERED INDEX [IX_NONCLUS_Atomic_ApplicationAssignedTo_RecordInsertedAt_Remarks]ON [Atomic].[ApplicationAssignedTo] ([RecordInsertedAt],[Remarks])
# 	</sql>
# </changeSet>
#
# <changeSet author="msappidi" id="AddIndex-IX_NONCLUS_Atomic_ApplicationAssignedToInvestigator_RecordInsertedAt_Remarks" objectQuotingStrategy="QUOTE_ALL_OBJECTS">
# 	<sql endDelimiter="\nGO" splitStatements="true" stripComments="true">
# ...
